# %%
import pandas as pd
import os
import sys
REPO_PATH = 'C:/IDE/repository/liquid_vapor_database'
sys.path.append(REPO_PATH)
from src.database_operations import add_phase_equilibrium, create_database, search_mixtures

# %%
import pytesseract
import os
import cv2


folder_path = f'{REPO_PATH}/pdf_data/page_130'


if os.path.exists(folder_path):
    files = os.listdir(folder_path)    
else:
    print("Указанная папка не существует")

def extract_text_from_images(img_path, custom_config=r'--oem 3 --psm 6'):    
    if os.path.exists(img_path):
        img = cv2.imread(img_path)
        text = pytesseract.image_to_string(img, config=custom_config, lang='rus+eng')
        print(text)
        return text
    else:
        print(f'Изображения по адресу {img_path} не существует')
        
extract_text_from_images(folder_path + '/' + files[3])

# %%
import openai

def process_ocr_text_by_pages(text, api_key, prompt, engine='gpt-3.5-turbo-1106'):    

    # Создание экземпляра клиента OpenAI
    client = openai.OpenAI(api_key=api_key)

    processed_text = []
    
    req = prompt + text

    # Запрос к GPT API
    response = client.chat.completions.create(
        model=engine,
        messages=[{"role": "user", "content": req}],
    )

    processed_text.append(response.choices[0].message.content)

    return '\n'.join(processed_text)

api_key = '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'

prompt = """
Инструкция
Извлеките названия химических веществ из предоставленного текста. \
    Названия веществ всегда написаны заглавными буквами на русском языке.\
        Иногда текст может определиться неправильно и вместо русских букв там будет набор символов.\
            В таком случае попробуй подобрать максимально похожие русские буквы, которые неправильно установил OCR.\
        могут быть разделены дефисом или пробелом, и обычно следуют после символа "№", \
            хотя номер может отсутствовать. Каждое упоминание названия в тексте уникально. В вашем ответе перечислите все названия химических веществ, найденные в тексте в формате JSON, где ключ - это номер таблицы, а значение - названия веществ, разделённые через дефис.

Примеры
Вход:
№2 ВОДОРОД—ДЕЙТЕРИЙ [1031]
H,—D,
a И И ИЕ:
О А ЗОО | fo

JSON ответ:
{
"2": "ВОДОРОД-ДЕЙТЕРИЙ"
}

Вход:
№3 ВОДОРОД A3OT [1052]
. | y | ; | р. ana | : | y | | P, ara
| | | | | | |

JSON ответ:
{
"3": "ВОДОРОД-A3OT"
}

Вход:
№4 ВОДОРОД— АЗОТ [210]
° H,— М,
рр ре
z | y | i | Р, ата | x | y | t | P,ata
oo
_ | р г | ал afi | У о or | or. ff | no pf | goat» ar Of), mir,

JSON ответ:
{
"4": "ВОДОРОД-A3OT"
}

Этот промпт помогает AI понять, что от него требуется извлечь конкретные названия химических веществ из текста\
    и представить их в чётко определённом формате JSON, с учётом особенностей их написания и размещения в тексте.
"""

def extract_text_from_images(img_path, custom_config=r'--oem 3 --psm 6'):    
    if os.path.exists(img_path):
        img = cv2.imread(img_path)
        text = pytesseract.image_to_string(img, config=custom_config, lang='rus')
        print(text)
        return text
    else:
        print(f'Изображения по адресу {img_path} не существует')

# %%
NUM_PAGE = 146

folder_path = f'{REPO_PATH}/pdf_data/page_{NUM_PAGE}'

if os.path.exists(folder_path):
    files = os.listdir(folder_path)
    files = [file for file in files if 'metadata' and 'png' in file]    
else:
    print("Указанная папка не существует")
          
text = extract_text_from_images(folder_path + '/' + files[1])      
result = process_ocr_text_by_pages(text, api_key, prompt )

print(result)
# Out:
# ИИ ПО | ое. | =. | 9.9 | | 130
# № 37 ЭТАН— СЕРОВОДОРОД [663]
# СН,—Н.8
# А
# ро | 1 у Е | Р, ата, я Е | у + | Р, ата
# | | | | т ] ии
#
# JSON ответ:
# {
# "37": "ЭТАН-СЕРОВОДОРОД"
# }

# %%
import openai
import re

def process_ocr_text_by_pages(text, api_key, prompt, engine='gpt-3.5-turbo-1106'):    

    # Создание экземпляра клиента OpenAI
    client = openai.OpenAI(api_key=api_key)

    processed_text = []
    
    req = prompt + text

    # Запрос к GPT API
    response = client.chat.completions.create(
        model=engine,
        messages=[{"role": "user", "content": req}],
    )

    processed_text.append(response.choices[0].message.content)

    return '\n'.join(processed_text)
# Out:
# 'metadata_1.png'
